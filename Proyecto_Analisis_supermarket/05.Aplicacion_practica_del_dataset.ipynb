# %% [markdown]
# Propuesta de Mejora en Estrategias de Marketing y Gestión de Inventario:
#
# Estrategias de Marketing Personalizadas:
#
# Objetivo: Incrementar las ventas y la satisfacción del cliente.
# Acción: Implementar campañas de marketing específicas basadas en las calificaciones y el comportamiento de compra de los clientes. Por ejemplo, ofrecer descuentos en productos con calificaciones altas en sucursales con menores ventas.
#
# Optimización de Inventario:
#
# Objetivo: Reducir el exceso de stock y asegurar la disponibilidad de productos populares.
# Acción: Ajustar el inventario basándose en las líneas de productos más vendidas y en las tendencias de ventas diarias.
#
# 2. Implementación de la Propuesta en un Contexto Real
# Pasos para la Ejecución:
#
# Análisis Detallado de las Calificaciones:
#
# Examinar las distribuciones de calificaciones por sucursal y línea de producto para identificar áreas de mejora.
# Desafío: Asegurar que todas las calificaciones sean consideradas y no solo las más recientes.
#
# Campañas de Marketing Personalizadas:
#
# Diseñar campañas de marketing dirigidas a las sucursales con menores ventas, utilizando productos que tienen altas calificaciones y son populares entre los clientes.
# Desafío: Coordinar con el equipo de marketing para implementar campañas efectivas y medir su impacto.
#
# Optimización del Inventario:
#
# Utilizar los datos de ventas para ajustar los niveles de inventario, asegurando que los productos más vendidos estén siempre disponibles y reduciendo el exceso de stock de productos menos populares.
#
# Desafío: Necesidad de un sistema de gestión de inventario eficiente y actualizado.
#
# Análisis de Ventas por Día de la Semana:
#
# Analizar las ventas diarias para identificar patrones y ajustar las estrategias de personal y promoción en consecuencia.
# Desafío: Ajustar las operaciones diarias sin afectar la experiencia del cliente.
#
# Relación entre Precio Unitario y Cantidad:
#
# Evaluar la correlación entre el precio unitario y la cantidad comprada para optimizar la estrategia de precios.
# Desafío: Implementar cambios de precios sin afectar negativamente las ventas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilo de gráficos
sns.set(style="whitegrid")

# Ruta al archivo CSV limpio (ajusta la ruta según tu entorno)
file_path_cleaned = r'C:\Users\Scarlett\Documents\Mi_Proyecto_\Proyecto_Analisis_supermarket\data\supermarket_sales_cleaned.csv'

# Cargar el dataset limpio
try:
    df_cleaned = pd.read_csv(file_path_cleaned)
    print("Dataset limpio cargado correctamente.")
    
    # Crear el gráfico de barras
    plt.figure(figsize=(12, 8))
    sns.barplot(x='Total', y='Product line', data=df_cleaned, estimator=sum, ci=None)
    plt.title('Ventas Totales por Línea de Producto')
    plt.xlabel('Ventas Totales')
    plt.ylabel('Línea de Producto')
    plt.show()

except FileNotFoundError:
    print(f"El archivo limpio no se encuentra en la ruta especificada: {file_path_cleaned}")
except Exception as e:
    print(f"Ocurrió un error: {e}")
# Out:
# Dataset limpio cargado correctamente.
# C:\Users\Scarlett\AppData\Local\Temp\ipykernel_15080\4183506811.py:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Total', y='Product line', data=df_cleaned, estimator=sum, ci=None)

# %% [markdown]
# Hallazgo:
# Las líneas de productos como 'Health and beauty' y 'Electronic accessories' generan mayores ingresos.
#
# Propuesta:
# Aumentar el stock y las promociones en estas líneas de productos para maximizar las ventas.
